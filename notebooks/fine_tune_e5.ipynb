# %% [markdown]
# # Fine-tuning multilingual-e5-small для Avito
#
# Цель: дообучить `intfloat/multilingual-e5-small` на парах `(query, item)` из `train.parquet`, чтобы улучшить `dense` retrieval.

# %%
import os, sys
sys.path.insert(0, '..')
from src.retrieval.dense import fine_tune_model
fine_tune_model()
# Out:
# [18:23:26] Fine-tuning e5 на train...
# ...
# Computing widget examples:   0%|          | 0/1 [00:00<?, ?example/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 2, 'bos_token_id': 0, 'pad_token_id': 1}.
# /Users/anatolii/PycharmProjects/venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:759: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   super().__init__(loader)
#     <div>
#
#       <progress value='3125' max='3125' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3125/3125 43:09, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
# ...

# %% [markdown]
# ## Результат
#
# Модель сохраняется в `models/multilingual-e5-small-finetuned/`. После этого `dense.py` можно изменить, чтобы загружать дообученную модель вместо базовой (`MODEL_DIR`).
